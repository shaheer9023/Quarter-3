# %% [markdown]
# <a href="https://colab.research.google.com/github/shaheer9023/Quarter-3/blob/main/imageReader.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import google.generativeai as genai  # AI library import ki
from PIL import Image  # Image handling ke liye Pillow
from io import BytesIO  # Image data bytes me handle karne ke liye
from IPython.display import display  # Notebook me image show karne ke liye
import requests  # URL se image fetch karne ke liye

genai.configure(api_key="AIzaSyCtrVX7O1eN87cAFOd8GdjrO0y_tLRPjtQ")  # API key set ki

model = genai.GenerativeModel("gemini-1.5-flash")  # AI model select kiya

url = "https://plus.unsplash.com/premium_photo-1666901328734-3c6eb9b6b979?w=500&auto=format&fit=crop&q=60&ixlib=rb-4.0.3&ixid=M3wxMjA3fDB8MHxzZWFyY2h8NXx8cmFuZG9tfGVufDB8fDB8fHww"  # Image URL
response = requests.get(url)  # Image fetch ki
img = Image.open(BytesIO(response.content))  # Bytes se image open ki
display(img)  # Image show ki

prompt = f"explain image in details  : {url}"  # AI ko prompt diya
response = model.generate_content([prompt,img])  # Response liya
print(response.text)  # Result print kiya
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>

# %% [markdown]
# The image is a digital rendering depicting a surreal and dreamlike landscape.
#
#
# Here's a breakdown of the scene:
#
# * **Foreground:** A field of lavender-colored flowers stretches across the foreground, creating a soft, textured base for the scene.  The flowers are a consistent pale purple, suggesting a cultivated field or a naturally occurring expanse.
#
# * **Midground:** A single, striking tree stands in the center of the lavender field. The tree has a full, rounded crown of pale pink or coral leaves, giving it an almost ethereal quality. The trunk is thick and appears to be somewhat sculpted or unusually textured, possibly hinting at a stylized or symbolic representation rather than a realistic tree.
#
# * **Background:** A large, pale blue and white moon dominates the background. It's not a typical depiction of a moon; its surface is smooth and softly lit, creating a gentle, calming atmosphere. The sky transitions from a pale blue at the top to a soft pink near the horizon, adding to the dreamy ambiance. Rolling hills in the background are also a pale pink/purple, coordinating with the lavender and the tree.
#
#
# **Overall Impression:** The image conveys a sense of peace, tranquility, and otherworldliness. The pastel color palette, the solitary tree, and the oversized moon combine to create a scene that feels both beautiful and slightly mysterious. It evokes a feeling of fantasy or a dream-like state.  The scene is highly stylized and seemingly artificial in its perfection, suggestive of digital art or a digitally enhanced photograph.
